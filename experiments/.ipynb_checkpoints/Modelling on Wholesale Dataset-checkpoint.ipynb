# %% [markdown]
# # Wholesale Customers
#
# Description:
# * 440 rows, 2 parent and 6 child features
#
# Parent features:
# * Channel, Region
#
# Child features:
# * Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen
#
# Source: https://www.kaggle.com/binovi/wholesale-customers-data-set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ws = pd.read_csv("../data/wholesale.csv")

# %%
parent = ws[['Channel', 'Region']]
parent.head()
# Out:
#    Channel  Region
# 0        2       3
# 1        2       3
# 2        2       3
# 3        1       3
# 4        2       3

# %%
child = ws[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]
child.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
import tensorflow as tf
import sys
sys.path.append("C:/Users/notes/grab")

X = parent.values.astype(np.float32)
y = child.values.astype(np.float32)
dataset = tf.data.Dataset \
    .from_tensor_slices((X, y)) \
    .shuffle(X.size).batch(40)

# %%
from model.gmm import GMM
# Build GMM
gmm = GMM(x_features=X.shape[1],
          y_features=y.shape[1],
          n_components=100,
          n_hidden=50)
gmm.fit(dataset, epochs=1000, plot=True, verbose=True, logdir='gmm_wholesale')
# Out:
# 0 [NLL: 156333632.0]
# 100 [NLL: 52361.96875]
# 200 [NLL: 23594.302734375]
# 300 [NLL: 2760.087646484375]
# 400 [NLL: 1583.6563720703125]
# 500 [NLL: 2133.117431640625]
# 600 [NLL: 1322.8643798828125]
# 700 [NLL: 474.2916564941406]
# 800 [NLL: 132.35032653808594]
# 900 [NLL: 251.2938995361328]
# <tf.Tensor: shape=(), dtype=float32, numpy=115.971695>

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/gmm_wholesale
# Out:
# Reusing TensorBoard on port 6006 (pid 77208), started 0:08:41 ago. (Use '!kill 77208' to kill it.)
#       <iframe id="tensorboard-frame-da69aa5293b35400" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-da69aa5293b35400");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
y_hat = gmm.sample(X)

# %%
from visualisation.visualisation import Visualisation

gmm_viz = Visualisation(gmm, X, y)
for i in range(y.shape[1]):
    gmm_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from performance.performance import prob_overlap, kl, js

p, q = prob_overlap(y, y_hat, bins=20)
print("KL:", kl(p, q))
print("JS:", js(p, q))
# Out:
# (6, 3)
# KL: 0.283806193173886
# JS: 0.02522540598855735

# %%
from model.cgan import CGAN

cgan = CGAN(x_features=X.shape[1],
            y_features=y.shape[1],
            latent_dim=32)

cgan.fit(dataset, epochs=1000, verbose=True, logdir="cgan_supermarket")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           528         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           48          input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32)           0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           528         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            102         dense_2[0][0]
# ==================================================================================================
# Total params: 1,206
# Trainable params: 1,206
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           48          input_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           112         input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           528         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            17          dropout[0][0]
# ==================================================================================================
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 0 [D loss: -0.07580004632472992] [G loss: 0.001804823288694024]
# 100 [D loss: -7.96730375289917] [G loss: 0.0035101245157420635]
# 200 [D loss: -6.156209945678711] [G loss: -0.02874807082116604]
# 300 [D loss: -6.190406322479248] [G loss: -0.10844671726226807]
# 400 [D loss: -6.332126617431641] [G loss: -0.2473365068435669]
# 500 [D loss: -5.888004302978516] [G loss: -0.47638219594955444]
# 600 [D loss: -6.996606349945068] [G loss: -0.8124567270278931]
# 700 [D loss: -6.4682159423828125] [G loss: -1.2462387084960938]
# 800 [D loss: -6.492927551269531] [G loss: -1.744349479675293]
# 900 [D loss: -3.8794212341308594] [G loss: -2.2798609733581543]

# %%
# %load_ext tensorboard
# %tensorboard --logdir experiments/logs/cgan_supermarket
# Out:
# Reusing TensorBoard on port 6006 (pid 33956), started 2 days, 22:48:39 ago. (Use '!kill 33956' to kill it.)
#       <iframe id="tensorboard-frame-63ca8403f022e082" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-63ca8403f022e082");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
y_hat = cgan.sample(X)

# %%
from visualisation.visualisation import Visualisation

cgan_viz = Visualisation(cgan, X, y)
for i in range(y.shape[1]):
    cgan_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from performance.performance import prob_overlap, kl, js

p, q = prob_overlap(y, y_hat, bins=20)
print("KL:", kl(p, q))
print("JS:", js(p, q))
# Out:
# KL: -0.08771038679089105
# JS: 0.01928324658466985
