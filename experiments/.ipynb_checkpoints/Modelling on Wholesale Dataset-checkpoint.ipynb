# %% [markdown]
# # Supermarket Sales
#
# Description:
# * 440 rows, 2 parent and 6 child features
#
# Parent features:
# * Channel, Region
#
# Child features:
# * Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen
#
# Source: https://www.kaggle.com/binovi/wholesale-customers-data-set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ws = pd.read_csv("../data/wholesale.csv")

# %%
parent = ws[['Channel', 'Region']]
parent.head()
# Out:
#    Channel  Region
# 0        2       3
# 1        2       3
# 2        2       3
# 3        1       3
# 4        2       3

# %%
child = ws[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]
child.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
import tensorflow as tf
import sys
sys.path.append("C:/Users/notes/grab")

X = parent.values.astype(np.float32)
y = child.values.astype(np.float32)
dataset = tf.data.Dataset \
    .from_tensor_slices((X, y)) \
    .shuffle(X.size).batch(40)

# %%
from model.gmm import GMM
# Build GMM
gmm = GMM(x_features=X.shape[1],
          y_features=y.shape[1],
          n_components=50,
          n_hidden=20, verbose=True)
gmm.fit(dataset, epochs=1000, plot=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 20)           60          input_4[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 50)           1050        dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 300)          6300        dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 300)          6300        dense_12[0][0]
# ==================================================================================================
# Total params: 13,710
# Trainable params: 13,710
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 0 [NLL: 120522752.0]
# 100 [NLL: 123470.203125]
# 200 [NLL: 17355.1171875]
# 300 [NLL: 15365.134765625]
# 400 [NLL: 4967.298828125]
# 500 [NLL: 868.8773193359375]
# 600 [NLL: 977.3380737304688]
# 700 [NLL: 241.71658325195312]
# 800 [NLL: 209.1457977294922]
# 900 [NLL: 254.61495971679688]
# <tf.Tensor: shape=(), dtype=float32, numpy=111.62841>

# %%
y_hat = gmm.sample(X)

# %%
from visualisation.visualisation import Visualisation

gmm_viz = Visualisation(gmm, X, y)
for i in range(y.shape[1]):
    gmm_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from model.cgan import CGAN

cgan = CGAN(x_features=X.shape[1],
            y_features=y.shape[1],
            latent_dim=32,
            batch_size=40)

cgan.fit(dataset, epochs=1000)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           528         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           48          input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32)           0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           528         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            102         dense_2[0][0]
# ==================================================================================================
# Total params: 1,206
# Trainable params: 1,206
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           48          input_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           112         input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           528         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            17          dropout[0][0]
# ==================================================================================================
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 0 [D loss: 0.033264100551605225] [G loss: 0.0018503883620724082]
# 100 [D loss: -7.148496150970459] [G loss: -0.0015602016355842352]
# 200 [D loss: -7.273433208465576] [G loss: -0.04374637082219124]
# 300 [D loss: -7.084318161010742] [G loss: -0.12482502311468124]
# 400 [D loss: -8.007938385009766] [G loss: -0.29560524225234985]
# 500 [D loss: -6.764549255371094] [G loss: -0.501358151435852]
# 600 [D loss: -6.553956508636475] [G loss: -0.9162979125976562]
# 700 [D loss: -6.00660514831543] [G loss: -1.2079156637191772]
# 800 [D loss: -5.1642866134643555] [G loss: -1.8380542993545532]
# 900 [D loss: -5.079163551330566] [G loss: -1.815625786781311]

# %%
y_hat = cgan.sample(X)

# %%
cgan_viz = Visualisation(cgan, X, y)
for i in range(y.shape[1]):
    cgan_viz.plot_violin(y[:,i], y_hat[:,i])
