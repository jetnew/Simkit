# %% [markdown]
# # Supermarket Sales
#
# Description:
# * 1000 rows, 5 parent and 5 child features
#
# Parent features:
# * Branch, City, Customer type, Gender, Product line, Unit price
#
# Child features:
# * Quantity, Tax 5%, Total, Date, Time, Payment
#
# Source: https://www.kaggle.com/aungpyaeap/supermarket-sales

# %%
import sys
sys.path.append("C:/Users/notes/grab")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sm = pd.read_csv("../data/supermarket.csv")

# %%
parent = sm[['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Unit price']]
parent.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31

# %%
child = sm[['Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment']]
child.head()
# Out:
#    Quantity   Tax 5%     Total       Date   Time      Payment
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(sparse=False)
t_parent = enc.fit_transform(parent[['Branch', 'City', 'Customer type', 'Gender', 'Product line']])

X = np.append(t_parent, parent[['Unit price']], axis=1)

# %%
enc = OneHotEncoder(sparse=False)
t_child = enc.fit_transform(child[['Payment']])

child_month = pd.to_datetime(child['Date']).dt.month
child_day = pd.to_datetime(child['Date']).dt.day
child_hour = pd.to_datetime(child['Time']).dt.hour
child_dt = pd.concat([child_month, child_day, child_hour], axis=1).values

y = np.concatenate([child[['Quantity', 'Tax 5%', 'Total']], t_child, child_dt], axis=1)

# %%
import tensorflow as tf

X = X.astype(np.float32)
y = y.astype(np.float32)
dataset = tf.data.Dataset \
    .from_tensor_slices((X, y)) \
    .shuffle(X.size).batch(32)

# %%
from model.gmm import GMM

# Build GMM
gmm = GMM(x_features=X.shape[1],
          y_features=y.shape[1],
          n_components=100,
          n_hidden=50)
gmm.fit(dataset, epochs=1000, plot=True, verbose=True, logdir="gmm_supermarket")
y_hat = gmm.sample(X)
# Out:
# WARNING:tensorflow:From C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\ops\linalg\linear_operator_diag.py:166: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.
# 0 [NLL: 482.7187805175781]
# 10 [NLL: 75.03630828857422]
# 20 [NLL: 36.86175537109375]
# 30 [NLL: 25.522037506103516]
# 40 [NLL: 25.727046966552734]
# 50 [NLL: 23.744426727294922]
# 60 [NLL: 23.130016326904297]
# 70 [NLL: 22.96133041381836]
# 80 [NLL: 25.493919372558594]
# 90 [NLL: 23.588796615600586]

# %%
# %load_ext tensorboard
# %tensorboard --logdir experiments/logs/gmm_supermarket
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 94676), started 0:04:58 ago. (Use '!kill 94676' to kill it.)
#       <iframe id="tensorboard-frame-da9b0fc84bfad244" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-da9b0fc84bfad244");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
from visualisation.visualisation import Visualisation

gmm_viz = Visualisation(gmm, X, y)
for i in range(y.shape[1]):
    gmm_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from performance.performance import prob_overlap, kl, js

p, q = prob_overlap(y, y_hat, bins=10)
print("KL:", kl(p, q))
print("JS:", js(p, q))
# Out:
# KL: 1.8508202483663
# JS: 0.07674776985984055

# %%
from model.cgan import CGAN

cgan = CGAN(x_features=X.shape[1],
            y_features=y.shape[1],
            latent_dim=32)

cgan.fit(dataset, epochs=1000, verbose=True, logdir="cgan_supermarket")
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 32)]         0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 16)           528         input_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           288         input_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32)           0           dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 16)           528         concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 9)            153         dense_14[0][0]
# ==================================================================================================
# Total params: 1,497
# Trainable params: 1,497
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 16)           288         input_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 16)           160         input_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32)           0           dense_16[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 16)           528         concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            17          dropout_1[0][0]
# ==================================================================================================
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 0 [D loss: -0.006868137512356043] [G loss: 0.005749778356403112]
# 100 [D loss: -0.006873618811368942] [G loss: -0.0013115928741171956]
# 200 [D loss: -0.004214324057102203] [G loss: 0.034143224358558655]
# 300 [D loss: -0.005425196141004562] [G loss: 0.033315666019916534]
# 400 [D loss: -0.004416927695274353] [G loss: 0.03109612688422203]
# 500 [D loss: -0.004516512155532837] [G loss: 0.03838995844125748]
# 600 [D loss: -0.004506930708885193] [G loss: 0.02842060849070549]
# 700 [D loss: -0.0016513913869857788] [G loss: 0.029608316719532013]
# 800 [D loss: -0.003916475921869278] [G loss: 0.035443827509880066]
# 900 [D loss: -0.0065459683537483215] [G loss: 0.03189680352807045]

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/cgan_supermarket
# Out:
# Reusing TensorBoard on port 6006 (pid 4160), started 0:07:19 ago. (Use '!kill 4160' to kill it.)
#       <iframe id="tensorboard-frame-96380a4fbf8e1bce" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-96380a4fbf8e1bce");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
from visualisation.visualisation import Visualisation

y_hat = cgan.sample(X)
cgan_viz = Visualisation(cgan, X, y)
for i in range(y.shape[1]):
    cgan_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from performance.performance import prob_overlap, kl, js

p, q = prob_overlap(y, y_hat, bins=10)
print("KL:", kl(p, q))
print("JS:", js(p, q))
# Out:
# KL: 1.3455613889457259
# JS: 0.061579323351224596
