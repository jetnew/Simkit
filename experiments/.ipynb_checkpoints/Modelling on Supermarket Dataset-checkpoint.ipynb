# %% [markdown]
# # Supermarket Sales
#
# Description:
# * 440 rows, 2 parent and 6 child features
#
# Parent features:
# * Channel, Region
#
# Child features:
# * Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen
#
# Source: https://www.kaggle.com/binovi/wholesale-customers-data-set

# %%
import sys
sys.path.append("C:/Users/notes/grab")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sm = pd.read_csv("../data/supermarket.csv")

# %%
parent = sm[['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Unit price']]
parent.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31

# %%
child = sm[['Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment']]
child.head()
# Out:
#    Quantity   Tax 5%     Total       Date   Time      Payment
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(sparse=False)
t_parent = enc.fit_transform(parent[['Branch', 'City', 'Customer type', 'Gender', 'Product line']])

X = np.append(oh_parent, parent[['Unit price']], axis=1)

# %%
enc = OneHotEncoder(sparse=False)
t_child = enc.fit_transform(child[['Payment']])

child_month = pd.to_datetime(child['Date']).dt.month
child_day = pd.to_datetime(child['Date']).dt.day
child_hour = pd.to_datetime(child['Time']).dt.hour
child_dt = pd.concat([child_month, child_day, child_hour], axis=1).values

y = np.concatenate([child[['Quantity', 'Tax 5%', 'Total']], t_child, child_dt], axis=1)

# %%
X = X.astype(np.float32)
y = y.astype(np.float32)
dataset = tf.data.Dataset \
    .from_tensor_slices((X, y)) \
    .shuffle(X.size).batch(32)

# %%
import sys
sys.path.append("C:/Users/notes/grab")
from model.gmm import GMM

# Build GMM
gmm = GMM(x_features=X.shape[1],
          y_features=y.shape[1],
          n_components=100,
          n_hidden=50, verbose=True)
gmm.fit(dataset, epochs=2000, plot=True)
y_hat = gmm.sample(X)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 50)           900         input_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 100)          5100        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 900)          45900       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 900)          45900       dense_4[0][0]
# ==================================================================================================
# Total params: 97,800
# Trainable params: 97,800
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 0 [NLL: 1354.78515625]
# 200 [NLL: 21.969762802124023]
# 400 [NLL: 21.450477600097656]
# 600 [NLL: 21.930572509765625]
# 800 [NLL: 21.498701095581055]
# 1000 [NLL: 21.81760597229004]
# 1200 [NLL: 20.04401397705078]
# 1400 [NLL: 20.62714958190918]
# 1600 [NLL: 20.432212829589844]
# 1800 [NLL: 21.38527488708496]

# %%
from visualisation.visualisation import Visualisation

gmm_viz = Visualisation(gmm, X, y)
for i in range(y.shape[1]):
    gmm_viz.plot_violin(y[:,i], y_hat[:,i])

# %%
from model.cgan import CGAN

cgan = CGAN(x_features=X.shape[1],
            y_features=y.shape[1],
            latent_dim=32,
            batch_size=32)

cgan.fit(dataset, epochs=1000)
y_hat = cgan.sample(X)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 16)           528         input_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 16)           288         input_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32)           0           dense_8[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 16)           528         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 9)            153         dense_10[0][0]
# ==================================================================================================
# Total params: 1,497
# Trainable params: 1,497
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 16)           288         input_5[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           160         input_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32)           0           dense_12[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 16)           528         concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16)           0           dense_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            17          dropout[0][0]
# ==================================================================================================
# Total params: 993
# Trainable params: 993
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-57cb1d6d1e39> in <module>
#       6             batch_size=32)
#       7
# ----> 8 cgan.fit(dataset, epochs=1000)
#       9 y_hat = cgan.sample(X)
#
# C:/Users/notes/grab\model\cgan.py in fit(self, dataset, epochs)
#      86         for epoch in range(epochs):
#      87             for X_train, y_train in dataset:
# ---> 88                 g_loss, d_loss = self.train_step(X_train, y_train)
#      89             with train_summary_writer.as_default():
#      90                 tf.summary.scalar('g_loss', g_loss, step=epoch)
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2417     """Calls a graph function specialized to the inputs."""
#    2418     with self._lock:
# -> 2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2775
#    2776       self._function_cache.missed.add(call_context_key)
# -> 2777       graph_function = self._create_graph_function(args, kwargs)
#    2778       self._function_cache.primary[cache_key] = graph_function
#    2779       return graph_function, args, kwargs
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2665             arg_names=arg_names,
#    2666             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2667             capture_by_value=self._capture_by_value),
#    2668         self._function_attributes,
#    2669         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     979         _, original_func = tf_decorator.unwrap(python_func)
#     980
# --> 981       func_outputs = python_func(*func_args, **func_kwargs)
#     982
#     983       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     439         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     440         # the function a weak reference to itself to avoid a reference cycle.
# --> 441         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     442     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     443
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\eager\function.py in bound_method_wrapper(*args, **kwargs)
#    3297     # However, the replacer is still responsible for attaching self properly.
#    3298     # TODO(mdan): Is it possible to do it here instead?
# -> 3299     return wrapped_fn(*args, **kwargs)
#    3300   weak_bound_method_wrapper = weakref.ref(bound_method_wrapper)
#    3301
#
# ~\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     966           except Exception as e:  # pylint:disable=broad-except
#     967             if hasattr(e, "ag_error_metadata"):
# --> 968               raise e.ag_error_metadata.to_exception(e)
#     969             else:
#     970               raise
#
# ValueError: in user code:
#
#     C:/Users/notes/grab\model\cgan.py:62 train_step  *
#         fake_y = self.generator([noise, X], training=True)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:927 __call__  **
#         outputs = call_fn(cast_inputs, *args, **kwargs)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\engine\network.py:719 call
#         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\engine\network.py:888 _run_internal_graph
#         output_tensors = layer(computed_tensors, **kwargs)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:927 __call__
#         outputs = call_fn(cast_inputs, *args, **kwargs)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\layers\merge.py:183 call
#         return self._merge_function(inputs)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\layers\merge.py:522 _merge_function
#         return K.concatenate(inputs, axis=self.axis)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\keras\backend.py:2709 concatenate
#         return array_ops.concat([to_dense(x) for x in tensors], axis)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\util\dispatch.py:180 wrapper
#         return target(*args, **kwargs)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\ops\array_ops.py:1606 concat
#         return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:1189 concat_v2
#         "ConcatV2", values=values, axis=axis, name=name)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\op_def_library.py:744 _apply_op_helper
#         attrs=attr_protos, op_def=op_def)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\func_graph.py:595 _create_op_internal
#         compute_device)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\ops.py:3327 _create_op_internal
#         op_def=op_def)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\ops.py:1817 __init__
#         control_input_ops, op_def)
#     C:\Users\notes\Anaconda3\envs\grab\lib\site-packages\tensorflow\python\framework\ops.py:1657 _create_c_op
#         raise ValueError(str(e))
#
#     ValueError: Dimension 0 in both shapes must be equal, but are 32 and 8. Shapes are [32] and [8]. for '{{node model_2/concatenate/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32](model_2/dense_8/BiasAdd, model_2/dense_9/BiasAdd, model_2/concatenate/concat/axis)' with input shapes: [32,16], [8,16], [] and with computed input tensors: input[2] = <1>.

# %%
cgan_viz = Visualisation(cgan, X, y)
for i in range(y.shape[1]):
    cgan_viz.plot_violin(y[:,i], y_hat[:,i])
