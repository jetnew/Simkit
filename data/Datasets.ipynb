# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Synthetic Data
#
# Synthetic data is normally distributed at 4 clusters:
# * X = (20,60), y = (100)
# * X = (20,80), y = (120)
# * X = (40,60), y = (140)
# * X = (40,80), y = (160)
#
# Samples = 4 * n, shuffled.

# %%
from synthetic import get_normal_data, plot_data

X, y = get_normal_data(1000, plot=True)

# %% [markdown]
# # Supermarket Sales
#
# Description:
# * 1000 rows, 5 parent and 5 child features
#
# Parent features:
# * Branch, City, Customer type, Gender, Product line, Unit price
#
# Child features:
# * Quantity, Tax 5%, Total, Date, Time, Payment
#
# Source: https://www.kaggle.com/aungpyaeap/supermarket-sales

# %%
sm = pd.read_csv("supermarket.csv")

# %%
sm.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
sm.hist(xlabelsize=0)
plt.show()

# %%
# Parent features
sm[['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Unit price']].head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31

# %%
# Child features
sm[['Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment']].head()
# Out:
#    Quantity   Tax 5%     Total       Date   Time      Payment
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet

# %% [markdown]
# # Wholesale Customers
#
# Description:
# * 440 rows, 2 parent and 6 child features
#
# Parent features:
# * Channel, Region
#
# Child features:
# * Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen
#
# Source: https://www.kaggle.com/binovi/wholesale-customers-data-set

# %%
ws = pd.read_csv("wholesale.csv")

# %%
ws.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
ws.hist(xlabelsize=0)
plt.show()

# %%
ws[['Channel', 'Region']].head()
# Out:
#    Channel  Region
# 0        2       3
# 1        2       3
# 2        2       3
# 3        1       3
# 4        2       3

# %%
ws[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']].head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185
